# %% [markdown]
# # HW4 Selection (rev. 4) updated 07-02-2565 17:75
#
# * Save a copy in Drive
# * เปลี่ยนชื่อ Notebook ให้เป็น HW4_xxxxxxxxxx.ipynb โดย xxxxxxxxxx เป็นรหัสประจำตัวนิสิต

# %% [markdown]
# ## (rev. 4)
#
# * เพิ่มคำอธิบายและตัวอย่างใน comment เพื่อให้ครอบคลุมมากขึ้น
# * เปลี่ยนชื่อ function replace_letters() ไปเป็น mark_used_letters() เพื่อให้สื่อความหมายมากขึ้น
# * check_correct_position คืนค่า new_guess_word, correct, new_puzzle_word เพื่อไม่ให้ไปนับซ้ำใน check_wrong_position

# %% [markdown]
# ## (rev. 3) 04-02-2565 23:45
#
# * แก้ bug ใน main()
# * ตัดการเขียนฟังก์ชัน `combine_word(s1, s2, default_ch)` และ
# `check_kth_letter(word, k, ch)`
# * เพิ่มให้เขียนฟังก์ชัน `position_in_word(ch, word)`, `check_correct_position(puzzle_word, guess_word)`, `check_wrong_position(puzzle_word, guess_word)`
# * เพิ่มตัวอย่าง การทดสอบให้ใน section "การทดสอบ"

# %% [markdown]
# ## (rev. 2) 4 กุมภาพันธ์ 2565 เวลา 15:00 น.
#
#
# * เพิ่มคำสั่งให้ไปเพิ่มสีในข้อความในฟังก์ชัน `show_game_status()`
# * `combine_word()` เพิ่มคำอธิบายว่า s1, s2 มีความยาว = 5 เสมอ
# * `check_kth_letter()` ปรับคำอธิบาย แก้ไขตัวอย่างให้ถูกต้อง
# * เพิ่มข้อห้ามใช้ `str.find(), str.replace()`
# * แก้ bug ใน `main()` ที่ทายถูกครั้งที่ 6 บอกว่าทายไม่ถูก

# %% [markdown]
# # WORDLE
#
# เกมทายศัพท์ WORDLE กำลังเป็นที่นิยมเล่นกันในโซเชียลมีเดีย โดยจะให้ผู้เล่นทายคำศัพท์ที่มี 5 ตัวอักษร ผู้เล่นต้องทายคำให้ถูกต้องภายใน 6 ครั้ง เมื่อผู้เล่นเอาไปแชร์ ก็แจะแสดงผลของการทาย จะแสดงออกมาเป็นสีเขียว เหลือง และเทา เวลาที่แชร์ออกไปให้โซเชียลมีเดียคนอื่นก็จะเห็นแต่เฉพาะที่เป็นตารางสีเขียวสีเหลืองสีเทา โดยไม่รู้ว่าเป็นคำอะไร ดังแสดงในรูปข้างล่าง

# %% [markdown]
# ![wordle_1](https://www.mycourseville.com//sites/all/modules/courseville/files/ckfinder/userfiles/100006056910939/files/wordle_1_61fa25ed7ed74.png)

# %% [markdown]
# นิสิตสามารถไปลองเล่นและอ่านกติกาของเกมทายคำศัพท์นี้ได้ที่ [ลองเล่นเกม Wordle](https://www.powerlanguage.co.uk/wordle/)
#
# ในการทายคำแต่ละครั้ง จะแสดงผลของการทายออกมา โดยใช้สีเป็นตัวบอกว่าตัวอักษรที่ใช้ในคำนั้นถูกต้องหรือไม่ อย่างไร

# %% [markdown]
# ![wordle_2](https://www.mycourseville.com//sites/all/modules/courseville/files/ckfinder/userfiles/100006056910939/files/wordle_2_61fa25f295972.png)

# %% [markdown]
# ## กฎการเล่น
#
# พยายามเดาคำศัพท์ให้ได้ภายใน 6 ครั้ง
#
# แต่ละครั้งจะต้องใส่คำศัพท์ที่มี 5 อักขระและมีความหมาย
#
# ในการเดาแต่ละครั้ง สีในช่องอักขระก็จะเปลี่ยนไปตามความใกล้เคียงของคำที่ทายกับคำศัพท์ปริศนา (แสดงตามภาพข้างบน)
# * ตัวอักขระ W ที่ทายอยู่ในคำศัพท์และถูกตำแหน่งด้วยจะเป็นสีเขียว
# * ตัวอักขระ I อยู่ในคำศัพท์แต่ไม่ตรงตำแหน่ง จะแสดงด้วยสีเหลือง
# * ตัวอักขระ U ไม่อยู่ในคำศัพท์ จะแสดงด้วยสีเทา
#
# ในระหว่างการเล่น ด้านล่างจะแสดงตัวอักษรภาษาอังกฤษทั้งหมดรวมทั้งแสดงว่าอักษรใดที่มีในคำปริศนาและตรงตำแหน่ง, มีในคำปริศนาแต่ไม่ตรงตำแหน่ง และไม่มีในคำปริศนา ตามรูปข้างล่าง

# %% [markdown]
# ![wordle_3](https://www.mycourseville.com//sites/all/modules/courseville/files/ckfinder/userfiles/100006056910939/files/wordle_3_61fa25f866a43.png)

# %% [markdown]
# # งานของนิสิต
#
# สิ่งที่จะให้นิสิตทำในการบ้านนี้ ก็คือเขียนโปรแกรมที่จะทำการตรวจการทายคำของผู้เล่นในแต่ละครั้งพร้อมทั้งแสดงผลของการทายคำในแต่ละครั้งว่าได้ผลเป็นอย่างไร รวมทั้งแสดงสถานะของตัวอักษรที่ใช้ไปแล้วด้วยว่าแต่ละตัวเป็นอย่างไร ตรงตำแหน่ง ไม่ตรงตำแหน่ง ไม่มีในคำ หรือยังไม่ถูกใช้ทาย
#
# ในเกมจริงๆ คำที่ใช้ทายจะต้องเป็นคำที่มีอยู่ในพจนานุกรม แต่ในการบ้านนี้ขอทำให้ง่ายขึ้นโดยอนุญาตให้ป้อน 5 อักษรใดๆ ก็ได้โดยไม่ต้องมีความหมาย
#
# 1. โปรแกรมนี้เขียนให้บางส่วนแล้ว ภาระนิสิตคือเขียนในฟังก์ชัน
# ```
# position_in_word(ch, word)
# check_correct_position(puzzle_word, guess_word)
# check_wrong_position(puzzle_word, guess_word)
# replace_kth_letter_in_str(original_str, k, ch)
# color_text(text, color)
# ```
#
# 2. ส่วนฟังก์ชัน
# ```
# get_word()
# get_five_letter_word()
# show_game_status(correct, wrong, not_used)
# replace_letter(original, old_letter, new_letter)
# mark_used_letters(letters, letters_to_remove)
# main()
# ```
# ไม่ต้องการแก้ไขใด ๆ (และก็ไม่จำเป็นต้องรู้ด้วยว่าทำงานอย่างไร)
#
#
#
# **หากนิสิตเขียนโปรแกรมที่เหลือให้โปรแกรมสมบูรณ์โดยใช้ความรู้เท่าที่ได้เรียนมา ไม่ใช้  while, for, หรือ library อื่นๆ ที่ยังไม่ได้สอน จะได้โบนัส 10% ของคะแนนที่ได้**
#
# `str.find(), str.index(), str.replace()` ยังไม่ได้เรียน ถ้าใช้จะไม่ได้คะแนนโบนัส

# %%
# ให้เขียนโปรแกรมในเซลล์นี้เท่านั้น ห้ามลบ/แก้ไข ข้อความในบรรทัดแรกนี้ 

import random
import string

def get_word():
    # สามารถเพิ่มคำใน words ได้
    words = ["HAPPY", "IMAGE", "TOURS", "FLOOD", "BLOCK", 
             "STORE", "AMONG", "TWEET", "OFTEN", "STILL",
             "STYLE", "LIGHT", "MIGHT", "WOULD", "SEVEN"]
    return random.choice(words).upper()

def get_five_letter_word():
    # คืนค่าเป็นคำที่มีความยาว = 5
    print('  Guess a five-letter word >> ', end='')
    guess = input()
    while len(guess) != 5:
        print('  Please enter a five-letter word >> ', end='')
        guess = input()
    return guess.upper()
            
def show_game_status(correct, wrong, not_used):
    correct = color_text(correct, 'green')
    wrong = color_text(wrong, 'yellow')
    print('  Correct letters - [{}]'.format(correct))
    print('  Wrong position - [{}]'.format(wrong))
    print('  Letters not used - [{}]'.format(not_used))

def replace_letter(original, old_letter, new_letter):
    # คืนค่าเป็นสตริงที่เปลี่ยน อักขระใน original จาก old_letter ไปเป็น new_letter
    # original เป็นสตริงที่ไม่มีตัวอักขระซ้ำกันแน่ ๆ
    if old_letter in original:
        k = original.find(old_letter)
        original = original[:k] + new_letter + original[k+1:]
    return original    

def mark_used_letters(letters, letters_to_remove):
    # เปลี่ยนทุกอักขระใน letters ที่อยู่ใน letters_to_remove ให้เป็น '-'
    for ch in letters_to_remove:
        # เปลี่ยนอักขระ ch ใน letters ให้เป็น '-'
        letters = replace_letter(letters, ch, '-')
    return letters

#------------------------------------------------------------------------
# เพิ่มรายละเอียดใน function ข้างล่างนี้
#------------------------------------------------------------------------
def position_in_word(ch, word):
    # คืนตำแหน่งแรกที่พบ ch ใน word โดยไล่จากซ้ายไปขวา ถ้าไม่มี ch ใน word คืน  -1
    #   ch มีความยาวเป็น 1 อักขระ
    #   word จะมีความยาวเป็น 5 อักขระเสมอ
    # ห้ามใช้ str.find(), str.index() แต่ให้เขียนเองให้ทำงานเหมือนกัน
    # ตัวอย่าง
    # position_in_word('A', 'ABCAB') คืนค่า 0
    # position_in_word('B', 'ABCAB') คืนค่า 1
    # position_in_word('C', 'ABCAB') คืนค่า 2
    # position_in_word('D', 'ABCAB') คืนค่า -1
    position = -1

    if word[0]==ch:
        position = 0
    else:
        if word[1]==ch:
            position = 1
        else:
            if word[2]==ch:
                position = 2
            else:
                if word[3]==ch:
                    position = 3
                else:
                    if word[4]==ch:
                        position = 4
    return position

def check_correct_position(puzzle_word, guess_word):
    # ตรวจสอบว่าในแต่ละตำแหน่งของ guess_word ตรงกับ puzzle_word หรือไม่
    # puzzle_word และ guess_word มี 5 ตัวอักขระแน่ๆ โดยในการตรวจสอบก็จะขีดตัวที่มีตำแหน่งตรงกันออกไปทีละตัว
    #   ทั้งที่ puzzle_word และ guess_word เพื่อไม่ไปตรวจซ้ำซ้อนภายหลัง
    # คืนค่าเป็น new_guess_word, correct, new_puzzle_word
    #   new_guess_word ตัดตัวที่ตรงตำแหน่งออก
    #   correct เป็นสตริง ที่อยู่ในรูปแบบ '?????' โดยที่ถ้าตำแหน่งไหนที่อักขระใน puzzle_word เหมือนกับ guess_word
    #           ก็ให้เปลี่ยน ? ตรงตำแหน่งนั้นให้เป็น ตัวอักขระ
    #   new_puzzle_word เป็นเหมือน puzzle_word แต่เปลี่ยนตำแหน่งที่ตำแหน่ง guess_word ตรงกันเป็น '-' 
    #     เพื่อจะได้ไม่เอาไปตรวจซ้ำ (ซึ่งก็คือ puzzle_word ที่ขีดตัวที่ตรงตำแหน่งทิ้ง)
    # ตัวอย่าง
    # check_correct_position('FLOOD', 'FXXXX') คืนค่า '-XXXX', 'F????', '-LOOD'
    # check_correct_position('FLOOD', 'FLXXX') คืนค่า '--XXX', 'FL???', '--OOD'
    # check_correct_position('FLOOD', 'FXOXX') คืนค่า '-X-XX', 'F?O??', '-L-OD'
    # check_correct_position('FLOOD', 'FXXOX') คืนค่า '-XX-X', 'F??O?', '-LO-D'
    # check_correct_position('FLOOD', 'FXOOX') คืนค่า '-X--X', 'F?OO?', '-L--D'
    # check_correct_position('FLOOD', 'FXOOD') คืนค่า '-X---', 'F?OOD', '-L---'
    # check_correct_position('FLOOD', 'FLOOD') คืนค่า '-----', 'FLOOD', '-----'

    correct = ''
    new_puzzle_word = puzzle_word
    new_guess_word = guess_word
    if puzzle_word[0]==guess_word[0]:
        correct += puzzle_word[0]
        new_puzzle_word=replace_kth_letter_in_str(new_puzzle_word, 0, '-')
        new_guess_word=replace_kth_letter_in_str(new_guess_word, 0, '-')
    else:
        correct+='?'
    if puzzle_word[1]==guess_word[1]:
        correct += puzzle_word[1]
        new_puzzle_word=replace_kth_letter_in_str(new_puzzle_word, 1, '-')
        new_guess_word=replace_kth_letter_in_str(new_guess_word, 1, '-')
    else:
        correct+='?'
    if puzzle_word[2]==guess_word[2]:
        correct += puzzle_word[2]
        new_puzzle_word=replace_kth_letter_in_str(new_puzzle_word, 2, '-')
        new_guess_word=replace_kth_letter_in_str(new_guess_word, 2, '-')
    else:
        correct+='?'
    if puzzle_word[3]==guess_word[3]:
        correct += puzzle_word[3]
        new_puzzle_word=replace_kth_letter_in_str(new_puzzle_word, 3, '-')
        new_guess_word=replace_kth_letter_in_str(new_guess_word, 3, '-')
    else:
        correct+='?'
    if puzzle_word[4]==guess_word[4]:
        correct += puzzle_word[4]
        new_puzzle_word=replace_kth_letter_in_str(new_puzzle_word, 4, '-')
        new_guess_word=replace_kth_letter_in_str(new_guess_word, 4, '-')
    else:
        correct+='?'
    

    return new_guess_word, correct, new_puzzle_word

def check_wrong_position(puzzle_word, guess_word):
    # ตรวจสอบว่ามีอักขระใดใน guess_word ว่ามีใน puzzle_word ในตำแหน่งอื่นๆ ที่ไม่ตรงกันหรือไม่
    # โดยตรวจไปทีละตัวแล้วมีการขีดอักขระที่พบใน puzzle_word ออก เพื่อไม่ไปนับซ้ำอีกเมื่อตรวจตัวต่อไป
    #
    # puzzle_word และ guess_word มี 5 ตัวอักขระแน่ๆ
    # puzzle_word และ guess_word เป็นผลลัพธ์ที่ได้มาจาก check_correct_position ดังนั้น
    #   จะไม่มีอักขระที่เหมือนกันในตำแหน่งเดียวกันแน่ๆ 
    # คืนค่าเป็น สตริงในรูปแบบ '*****' โดยแทนที่ '*' ด้วยีตัวอักขระของ guess_word ที่พบใน puzzle_word
    # ตัวอย่าง
    # check_wrong_position('FLOOD', 'DXXXX') คื่นค่า 'D****'
    # check_wrong_position('-LOOD', '-XXXX') คืนค่า '*****'
    # check_wrong_position('-LOOD', '-XDXX') คืนค่า '**D**'
    # check_wrong_position('-LOOD', '-OXXX') คืนค่า '*O***' (ตัวอักขระ O ใน puzzle_word > ใน guess_word)
    # check_wrong_position('-LOOD', '-XXXO') คืนค่า '****O'
    # check_wrong_position('-LOOD', '-OLXO') คืนค่า '*OL*O'
    # check_wrong_position('FLOOD', 'LFXXX') คื่นค่า 'LF***'
    # check_wrong_position('FLOOD', 'OOSTW') คื่นค่า 'OO***' (ตัวอักขระ O มีจำนวน > 1)
    # check_wrong_position('FLOOD', 'XXXXO') คื่นค่า '****O'
    # check_wrong_position('FLOOD', 'OODLF') คื่นค่า 'OODLF' 
    # check_wrong_position('FLOOD', 'OOLDL') คื่นค่า 'OOLD*' (ตัวอักขระ L ใน puzzle_word < ใน guess_word)
    # check_wrong_position('FLOOD', 'OFTEN') คื่นค่า 'OF***'
    wrong_position = ''
    if guess_word[0] in puzzle_word and guess_word[0]!='-':
        wrong_position += guess_word[0]
        puzzle_word = replace_kth_letter_in_str(puzzle_word, position_in_word(guess_word[0],puzzle_word), '-')
    else:
        wrong_position+='*'
    if guess_word[1] in puzzle_word and guess_word[1]!='-':
        wrong_position += guess_word[1]
        puzzle_word = replace_kth_letter_in_str(puzzle_word, position_in_word(guess_word[1],puzzle_word), '-')
    else:
        wrong_position+='*'
    if guess_word[2] in puzzle_word and guess_word[2]!='-':
        wrong_position += guess_word[2]
        puzzle_word = replace_kth_letter_in_str(puzzle_word, position_in_word(guess_word[2],puzzle_word), '-')
    else:
        wrong_position+='*'
    if guess_word[3] in puzzle_word and guess_word[3]!='-':
        wrong_position += guess_word[3]
        puzzle_word = replace_kth_letter_in_str(puzzle_word, position_in_word(guess_word[3],puzzle_word), '-')
    else:
        wrong_position+='*'
    if guess_word[4] in puzzle_word and guess_word[4]!='-':
        wrong_position += guess_word[4]
        puzzle_word = replace_kth_letter_in_str(puzzle_word, position_in_word(guess_word[4],puzzle_word), '-')
    else:
        wrong_position+='*'
    
    return wrong_position

def replace_kth_letter_in_str(original_str, k, ch):
    # คืนค่าเป็นสตริงใหม่ที่เปลี่ยนตัวที่ k ให้เป็น ch
    # หมายเหตุ ให้เขียนเองโดยใช้ string slicing ห้ามใช้คำสั่งจาก library อื่นๆ เช่น  str.replace()
    # ตัวอย่าง
    #   replace_kth_letter_in_str('ABCDE', 0, '-') คืนค่า '-BCDE'
    #   replace_kth_letter_in_str('ABCDE', 1, '-') คืนค่า 'A-CDE'
    #   replace_kth_letter_in_str('ABCDE', 2, '-') คืนค่า 'AB-DE'
    #   replace_kth_letter_in_str('ABCDE', 3, '-') คืนค่า 'ABC-E'
    #   replace_kth_letter_in_str('ABCDE', 4, '-') คืนค่า 'ABCD-'
    k=int(k)
    result = original_str[0:k]+ch+original_str[k+1:]
    return result

def color_text(text, color):
    # รหัสสีที่ใช้แสดง ห้ามเปลี่ยน
    white_on_green = '\033[37;42m'
    white_on_yellow = '\033[34;43m'
    normal = '\033[0;0m'
    # text มี 5 ตัวอักษรแน่ๆ 
    # color เป็นสตริง 
    #   ถ้า color เป็น 'green' ก็ให้แสดงอักขระภาษาอังกฤษใน text ที่มีพื้นหลังเป็นสีเขียว (ใช้ white_on_green)
    #   ถ้า color เป็น 'yellow' ก็ให้แสดงอักขระภาษาอังกฤษใน text ที่มีพื้นหลังเป็นสีเหลือง (ใช้ white_on_yellow)
    # ใส่สีให้เแพาะอักขระ 'A' ถึง 'Z' เท่านั้น โดยเอารหัสสีที่ให้มา มาเติมข้างหน้าสิ่งที่ต้องการเปลี่ยนสี แล้ว เอารหัส normal 
    #   มาต่อข้างหลังตัว เพื่อเปลี่ยนสีให้กลับมาเป็นปกติ
    # ลองเอา code ตัวอย่างไป run ดู แล้วมาประยุกต์ใช้ในการเขียนฟังก์ชั่นนี้
    # ch1 = '1'
    # ch2 = white_on_green + '2' + normal
    # ch3 = white_on_yellow + '3' + normal
    # ch4 = '4'
    # ch5 = white_on_yellow + '5' + normal
    # print(ch1 + ch2 + ch3 + ch4 + ch5)

    # ถ้าไม่ได้ทำอะไร ก็จะคืน text ตัวเดิมเพื่อให้โปรแกรมทั้งหมดยังทำงานได้
    # ในการเขียนฟังก์ชั่นนี้ให้เติมรหัสสีและตัวอักษรหรือข้อความที่จะแสดง
    # แล้วเก็บลงในตัวแปร colored_text เมื่อทำครบถ้วนให้ return colored_text แทน

    # ตัวอย่าง
    # print(color_text('????D', 'green')) จะแสดงตัวอักขระ 'D' ที่มีพื้นหลังเป็นสีเขียว
    # print(color_text('OO***', 'yellow')) จะแสดงตัวอักษร 'O' ที่มีพื้นหลังเป็นสีเหลืองทั้งสองตัว
    # print(color_text('S?T??', 'green')) จะแสดงตัวอักษร 'S' และ 'T' ที่มีพื้นหลังเป็นสีเขียว
    # print(color_text('H***T', 'yellow')) จะแสดงตัวอักษร 'H' และ 'T' ที่มีพื้นหลังเป็นสีเหลืองทั้งสองตัว

    colored_text = ''
    if color=='green':
        if text[0]=='?':
            colored_text+='?'
        else:
            colored_text+=(white_on_green+text[0]+normal)
        if text[1]=='?':
            colored_text+='?'
        else:
            colored_text+=(white_on_green+text[1]+normal)
        if text[2]=='?':
            colored_text+='?'
        else:
            colored_text+=(white_on_green+text[2]+normal)
        if text[3]=='?':
            colored_text+='?'
        else:
            colored_text+=(white_on_green+text[3]+normal)
        if text[4]=='?':
            colored_text+='?'
        else:
            colored_text+=(white_on_green+text[4]+normal)
        
    else:
        if text[0]=='*':
            colored_text+='*'
        else:
            colored_text+=(white_on_yellow+text[0]+normal)
        if text[1]=='*':
            colored_text+='*'
        else:
            colored_text+=(white_on_yellow+text[1]+normal)
        if text[2]=='*':
            colored_text+='*'
        else:
            colored_text+=(white_on_yellow+text[2]+normal)
        if text[3]=='*':
            colored_text+='*'
        else:
            colored_text+=(white_on_yellow+text[3]+normal)
        if text[4]=='*':
            colored_text+='*'
        else:
            colored_text+=(white_on_yellow+text[4]+normal)

    return colored_text
#------------------------------------------------------------------------
# สิ้นสุดส่วนที่นิสิตต้องทำ
#------------------------------------------------------------------------

def main():
    # ห้ามแก้ไขหรือเพิ่มเติม code ใน main()
    win = False
    puzzle_word = get_word()

    print("Do you want to show the puzzle word? [enter y or n]")
    show_puzzle = (input().upper() == 'Y')
    if show_puzzle:
        print('Puzzle word:', puzzle_word)

    correct_letters = '?????' 
    letters_wrong_position = '*****'
    letters_never_used = string.ascii_uppercase
    show_game_status(correct_letters, letters_wrong_position, letters_never_used)

    MAX_TRIES = 6
    for i in range(MAX_TRIES):
        print('-'*30)
        print('Try #', i+1)
        guess_word = get_five_letter_word()
        
        new_guess_word, correct_letters, new_puzzle_word = check_correct_position(puzzle_word, guess_word)
        letters_wrong_position = check_wrong_position(new_puzzle_word, new_guess_word)
        letters_never_used = mark_used_letters(letters_never_used, guess_word)
        
        show_game_status(correct_letters, letters_wrong_position, letters_never_used)
        if guess_word == puzzle_word:
            win = True
            break
        
    if win:
        print('You got it in {}/{}'.format(i+1, MAX_TRIES))
    else:
        print('You cannot solve this puzzle after', MAX_TRIES, 'times.')

main()
# Out:
# Do you want to show the puzzle word? [enter y or n]
# y
# Puzzle word: STILL
#   Correct letters - [?????]
#   Wrong position - [*****]
#   Letters not used - [ABCDEFGHIJKLMNOPQRSTUVWXYZ]
# ------------------------------
# Try # 1
#   Guess a five-letter word >> lllll
#   Correct letters - [???LL]
#   Wrong position - [*****]
#   Letters not used - [ABCDEFGHIJK-MNOPQRSTUVWXYZ]
# ------------------------------
# Try # 2
#   Guess a five-letter word >> lssll
#   Correct letters - [???LL]
#   Wrong position - [*S***]
#   Letters not used - [ABCDEFGHIJK-MNOPQR-TUVWXYZ]
# ------------------------------
# Try # 3
#   Guess a five-letter word >> ttttt
#   Correct letters - [?T???]
#   Wrong position - [*****]
#   Letters not used - [ABCDEFGHIJK-MNOPQR--UVWXYZ]
# ------------------------------
# Try # 4
#   Guess a five-letter word >> still
#   Correct letters - [STILL]
#   Wrong position - [*****]
#   Letters not used - [ABCDEFGH-JK-MNOPQR--UVWXYZ]
# You got it in 4/6

# %% [markdown]
# ## ตัวอย่างผลจากการ run

# %% [markdown]
# ### ตัวอักขระในคำปริศนาไม่มีตัวซ้ำ ทายถูกภายใน 6 ครั้ง
#
#
# ```
# Do you want to show the puzzle word? [enter y or n]
# y
# Puzzle word: WOULD
#   Correct letters - [?????]
#   Wrong position - [*****]
#   Letters not used - [ABCDEFGHIJKLMNOPQRSTUVWXYZ]
# ------------------------------
# Try # 1
#   Guess a five-letter word >> TOURS
#   Correct letters - [?OU??]
#   Wrong position - [*****]
#   Letters not used - [ABCDEFGHIJKLMN-PQ----VWXYZ]
# ------------------------------
# Try # 2
#   Guess a five-letter word >> MOUTH
#   Correct letters - [?OU??]
#   Wrong position - [*****]
#   Letters not used - [ABCDEFG-IJKL-N-PQ----VWXYZ]
# ------------------------------
# Try # 3
#   Guess a five-letter word >> WOULD
#   Correct letters - [WOULD]
#   Wrong position - [*****]
#   Letters not used - [ABC-EFG-IJK--N-PQ----V-XYZ]
# You got it in 3/6
# ```

# %% [markdown]
# ### ตัวอักขระในคำปริศนามีตัวซ้ำ ทายครบ 6 ครั้งแล้วยังไม่ถูก
#
#
#
# ```
# Do you want to show the puzzle word? [enter y or n]
# y
# Puzzle word: FLOOD
#   Correct letters - [?????]
#   Wrong position - [*****]
#   Letters not used - [ABCDEFGHIJKLMNOPQRSTUVWXYZ]
# ------------------------------
# Try # 1
#   Guess a five-letter word >> OOLLD
#   Correct letters - [????D]
#   Wrong position - [OOL**]
#   Letters not used - [ABC-EFGHIJK-MN-PQRSTUVWXYZ]
# ------------------------------
# Try # 2
#   Guess a five-letter word >> STORE
#   Correct letters - [??O??]
#   Wrong position - [*****]
#   Letters not used - [ABC--FGHIJK-MN-PQ---UVWXYZ]
# ------------------------------
# Try # 3
#   Guess a five-letter word >> MOUTH
#   Correct letters - [?????]
#   Wrong position - [*O***]
#   Letters not used - [ABC--FG-IJK--N-PQ----VWXYZ]
# ------------------------------
# Try # 4
#   Guess a five-letter word >> FIONY
#   Correct letters - [F?O??]
#   Wrong position - [*****]
#   Letters not used - [ABC---G--JK----PQ----VWX-Z]
# ------------------------------
# Try # 5
#   Guess a five-letter word >> FAOWX
#   Correct letters - [F?O??]
#   Wrong position - [*****]
#   Letters not used - [-BC---G--JK----PQ----V---Z]
# ------------------------------
# Try # 6
#   Guess a five-letter word >> FBOKD
#   Correct letters - [F?O?D]
#   Wrong position - [*****]
#   Letters not used - [--C---G--J-----PQ----V---Z]
# You cannot solve this puzzle after 6 times.
# ```

# %% [markdown]
# ## ตัวอย่างการแสดงผลแบบมีสี

# %% [markdown]
# ![wordle-4](https://www.mycourseville.com/sites/all/modules/courseville/files/ckfinder/userfiles/607893822/images/wordle-4_61fcd7145e60c.png)

# %% [markdown]
# ## การทดสอบ
#
# ส่วนนี้ไม่ใช่งานที่นิสิตต้องทำ แต่ มีส่วนทดสอบมาเป็นตัวช่วยในการทดสอบการทำงานของฟังก์ชันที่ให้เขียน นิสิตอาจจะต้องเพิ่มกรณีทดสอบให้ครอบคลุมกรณีต่างๆ ที่เป็นไปได้
#
# นิสิตสามารถแก้ไขได้ตามใจชอบเลยครับ

# %%
def test(x, r):
    print('{} - Expected: {}, Actual: {}'.format(x == r, x, r))

def test_position_in_word():
    r = position_in_word('A', 'ABCAB')
    test(0, r)
    r = position_in_word('B', 'ABCAB')
    test(1, r)
    r = position_in_word('C', 'ABCAB')
    test(2, r)
    r = position_in_word('D', 'ABCAB')
    test(-1, r)

def test_check_correct_position():
    print('--- check_correct_position() ---')
    r = check_correct_position('FLOOD', 'FXXXX')
    e = ('-XXXX', 'F????', '-LOOD')
    test(e, r)

def test_check_wrong_position():
    print('--- check_wrong_position() ---')
    r = check_wrong_position('FLOOD', 'DXXXX')
    e = 'D****'
    test(e, r)

def test_replace_kth_letter_in_str():
    print('--- replace_kth_letter_in_str() ---')
    r = replace_kth_letter_in_str('ABCDE', 0, '-')
    test('-BCDE', r)

def test_color_text():
    print('--- test_color_text() --')
    white_on_green = '\033[37;42m'
    white_on_yellow = '\033[34;43m'
    normal = '\033[0;0m'
    r = color_text('????D', 'green')
    e = '????' + white_on_green + 'D' + normal
#    e = '????\033[37;42mD\033[0;0m'
    test(e, r)

test_position_in_word()
test_check_correct_position()
test_check_wrong_position()
test_replace_kth_letter_in_str()
test_color_text()
# Out:
# True - Expected: 0, Actual: 0
# True - Expected: 1, Actual: 1
# True - Expected: 2, Actual: 2
# True - Expected: -1, Actual: -1
# --- check_correct_position() ---
# True - Expected: ('-XXXX', 'F????', '-LOOD'), Actual: ('-XXXX', 'F????', '-LOOD')
# --- check_wrong_position() ---
# True - Expected: D****, Actual: D****
# --- replace_kth_letter_in_str() ---
# True - Expected: -BCDE, Actual: -BCDE
# --- test_color_text() --
# True - Expected: ????D, Actual: ????D

# %% [markdown]
# # การส่งงาน
#
# * Save a copy in Drive
# * เปลี่ยนชื่อ Notebook ให้เป็น HW4_xxxxxxxxxx.ipynb โดย xxxxxxxxxx เป็นรหัสประจำตัวนิสิต
# * File->Download->Download .ipynb
# * ส่งไฟล์ที่ดาวน์โหลดได้ในระบบ ก่อนวันที่ 9 กุมภาพันธ์ 2565 เวลา 23:59 น.
