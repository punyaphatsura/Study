# %% [markdown]
# # Assignment 5

# %% [markdown]
# ### 1. Load "ModifiedEdibleMushroom.csv" data from the link below (note: this data set has been preliminarily prepared.)

# %% [markdown]
# https://github.com/pvateekul/2110446_DSDE_2023s2/blob/main/code/Week03_ML/mushroom2020_dataset.csv

# %%
# !pip install scikit-learn
# !pip install mlflow
# Out:
# Requirement already satisfied: scikit-learn in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: mlflow in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (2.10.2)
# Requirement already satisfied: click<9,>=7.0 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (3.0.0)
# Requirement already satisfied: entrypoints<1 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (0.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (3.1.41)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (6.0.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (4.25.2)
# Requirement already satisfied: pytz<2024 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (2023.4)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (2.31.0)
# Requirement already satisfied: packaging<24 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (23.2)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (7.0.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (0.4.4)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: docker<8,>=4.0.0 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (7.0.0)
# Requirement already satisfied: Flask<4 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: numpy<2 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: scipy<2 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (1.12.0)
# Requirement already satisfied: pandas<3 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (2.2.0)
# Requirement already satisfied: querystring-parser<2 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (2.0.26)
# Requirement already satisfied: scikit-learn<2 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (1.2.2)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (15.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (3.5.2)
# Requirement already satisfied: matplotlib<4 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (3.8.2)
# Requirement already satisfied: gunicorn<22 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (21.2.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from mlflow) (3.1.3)
# Requirement already satisfied: Mako in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.2)
# Requirement already satisfied: typing-extensions>=4 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from alembic!=1.10.0,<2->mlflow) (4.9.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from docker<8,>=4.0.0->mlflow) (2.2.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from Flask<4->mlflow) (3.0.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from Flask<4->mlflow) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from Flask<4->mlflow) (1.7.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from gitpython<4,>=2.1.0->mlflow) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from Jinja2<4,>=2.11->mlflow) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from matplotlib<4->mlflow) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from matplotlib<4->mlflow) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from matplotlib<4->mlflow) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from matplotlib<4->mlflow) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from matplotlib<4->mlflow) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from matplotlib<4->mlflow) (6.1.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: six in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from querystring-parser<2->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow) (2024.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from scikit-learn<2->mlflow) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from scikit-learn<2->mlflow) (3.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow) (5.0.1)

# %%
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv("https://github.com/pvateekul/2110446_DSDE_2023s2/raw/main/code/Week03_ML/mushroom2020_dataset.csv")

# %%
df.head()
# Out:
#    id label cap-shape cap-surface bruises odor gill-attachment gill-spacing  \
# 0   1     p         x           s       t    p               f            c
# 1   2     e         x           s       t    a               f            c
# 2   3     e         b           s       t    l               f            c
# 3   4     p         x           y       t    p               f            c
# 4   5     e         x           s       f    n               f            w
#
#   gill-size stalk-shape  ... ring-number ring-type spore-print-color  \
# 0         n           e  ...           o         p                 k
# 1         b           e  ...           o         p                 n
# 2         b           e  ...           o         p                 n
# 3         n           e  ...           o         p                 k
# 4         b           t  ...           o         e                 n
#
#   population habitat cap-color-rate gill-color-rate veil-color-rate  \
# 0          s       u            1.0             3.0             1.0
# 1          n       g            2.0             3.0             1.0
# 2          n       m            3.0             1.0             1.0
# 3          s       u            3.0             1.0             1.0
# 4          a       g            4.0             3.0             1.0
#
#   stalk-color-above-ring-rate  stalk-color-below-ring-rate
# 0                         1.0                          1.0
# 1                         1.0                          1.0
# 2                         1.0                          1.0
# 3                         1.0                          1.0
# 4                         1.0                          1.0
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5824 entries, 0 to 5823
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           5824 non-null   int64
#  1   label                        5764 non-null   object
#  2   cap-shape                    5824 non-null   object
#  3   cap-surface                  5797 non-null   object
#  4   bruises                      5725 non-null   object
#  5   odor                         5725 non-null   object
#  6   gill-attachment              5725 non-null   object
#  7   gill-spacing                 5694 non-null   object
#  8   gill-size                    5703 non-null   object
#  9   stalk-shape                  5703 non-null   object
#  10  stalk-root                   5793 non-null   object
#  11  stalk-surface-above-ring     5793 non-null   object
#  12  stalk-surface-below-ring     5793 non-null   object
#  13  veil-type                    5762 non-null   object
#  14  ring-number                  5762 non-null   object
#  15  ring-type                    5762 non-null   object
#  16  spore-print-color            5768 non-null   object
#  17  population                   5768 non-null   object
#  18  habitat                      5793 non-null   object
#  19  cap-color-rate               5797 non-null   float64
#  20  gill-color-rate              5703 non-null   float64
#  21  veil-color-rate              5762 non-null   float64
#  22  stalk-color-above-ring-rate  5793 non-null   float64
#  23  stalk-color-below-ring-rate  5762 non-null   float64
# dtypes: float64(5), int64(1), object(18)
# memory usage: 1.1+ MB

# %%
print("grill size NA number:",df["gill-size"].isna().sum())
# Out:
# grill size NA number: 121

# %% [markdown]
# ### 2. Drop rows where the target (label) variable is missing

# %%
df.dropna(subset=["label"], axis=0, inplace=True)
print("df shape:",df.shape)
# Out:
# df shape: (5764, 24)

# %% [markdown]
# ### 3. Drop the following variables:
#
# ```'id','gill-attachment', 'gill-spacing', 'gill-size','gill-color-rate','stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring-rate','stalk-color-below-ring-rate','veil-color-rate','veil-type'```

# %%
# print("df shape:",df.shape)
df.drop(columns=['id','gill-attachment', 'gill-spacing', 'gill-size','gill-color-rate','stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring-rate','stalk-color-below-ring-rate','veil-color-rate','veil-type'], inplace=True)
print("df shape:",df.shape)
# Out:
# df shape: (5764, 12)

# %%
df.head()
# Out:
#   label cap-shape cap-surface bruises odor stalk-shape ring-number ring-type  \
# 0     p         x           s       t    p           e           o         p
# 1     e         x           s       t    a           e           o         p
# 2     e         b           s       t    l           e           o         p
# 3     p         x           y       t    p           e           o         p
# 4     e         x           s       f    n           t           o         e
#
#   spore-print-color population habitat  cap-color-rate
# 0                 k          s       u             1.0
# 1                 n          n       g             2.0
# 2                 n          n       m             3.0
# 3                 k          s       u             3.0
# 4                 n          a       g             4.0

# %%
rows,cols = df.shape
missing_values = df.isnull().sum().sum()

print("Number of rows:", rows)
print("Number of digits:", cols)
print("Missing values:", missing_values)
# Out:
# Number of rows: 5764
# Number of digits: 12
# Missing values: 640

# %% [markdown]
# ### Use Pipeline

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline

num_cols = ['cap-color-rate']
cat_cols = ['cap-shape', 'cap-surface', 'bruises', 'odor', 'stalk-shape', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat']

# Initialize pipeline for numerical and categorical columns

num_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='mean')),
    ('scale', StandardScaler())])

cat_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('one-hot',OneHotEncoder(handle_unknown='ignore'))])

# %%
from sklearn.compose import ColumnTransformer

col_trans = ColumnTransformer(transformers=[
    ('num_pipeline', num_pipeline, num_cols),
    ('cat_pipeline', cat_pipeline, cat_cols)],
    n_jobs=-1)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model_pipeline = Pipeline(steps=[
    ('col_trans', col_trans),
    ('model', model)
])

# %%
from sklearn import set_config

set_config(display='diagram')
display(model_pipeline)
# Out:
# Pipeline(steps=[('col_trans',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer()),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['cap-color-rate']),
#                                                  ('cat_pipeline',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('one-hot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['cap-shape', 'cap-surface',
#                                                    'bruises', 'odor',
#                                                    'stalk-shape', 'ring-number',
#                                                    'ring-type',
#                                                    'spore-print-color',
#                                                    'population',
#                                                    'habitat'])])),
#                 ('model', RandomForestClassifier())])

# %%
from sklearn.model_selection import train_test_split

X = df[num_cols + cat_cols]
y = df['label']
# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=2020)

# %%
df.head()
# Out:
#   label cap-shape cap-surface bruises odor stalk-shape ring-number ring-type  \
# 0     p         x           s       t    p           e           o         p
# 1     e         x           s       t    a           e           o         p
# 2     e         b           s       t    l           e           o         p
# 3     p         x           y       t    p           e           o         p
# 4     e         x           s       f    n           t           o         e
#
#   spore-print-color population habitat  cap-color-rate
# 0                 k          s       u             1.0
# 1                 n          n       g             2.0
# 2                 n          n       m             3.0
# 3                 k          s       u             3.0
# 4                 n          a       g             4.0

# %% [markdown]
# ### Use MLFlow

# %%
# Importing all Libraries
import mlflow
import mlflow.sklearn

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, accuracy_score, classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold

import warnings
warnings.filterwarnings("ignore")

# %%
local_registry = "sqlite:///mlruns.db"
mlflow.set_tracking_uri(local_registry)
experiment_id = mlflow.set_experiment('test_experiment')

def eval_metrics(actual, pred):
    accuracy = accuracy_score(actual, pred)
    return accuracy

def train_model(param_grid, n_splits):

    # Starting the Experiement
    with mlflow.start_run():

        # Model building
        model = GridSearchCV(model_pipeline, param_grid, cv=StratifiedKFold(n_splits), scoring='accuracy')
        model.fit(X_train, y_train)   # Model Training
        y_pred = model.predict(X_test)  # Model Prediction on Testing data
        (accuracy) = eval_metrics(y_test, y_pred)

        print('Accuracy: {:.4f}'.format(accuracy))

        # Logging Parameters
        mlflow.log_param("param_grid", param_grid)
        mlflow.log_param("n_splits", n_splits)

        # Logging Metrics
        mlflow.log_metric("accuracy", accuracy_score(y_test, y_pred))

        # Model Logging
        mlflow.sklearn.log_model(model, 'model')

        return model

# %%
param_grid = {
    'model__criterion':['entropy', 'gini'],
    'model__max_depth': [2, 3, 6],
    'model__min_samples_leaf':[2, 5, 10],
    'model__n_estimators': [100, 200],
    'model__random_state':[2020]
    }
n_splits = 5

train_model(param_grid, n_splits)
# Out:
# Accuracy: 0.9965
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('col_trans',
#                                         ColumnTransformer(n_jobs=-1,
#                                                           transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('impute',
#                                                                                           SimpleImputer()),
#                                                                                          ('scale',
#                                                                                           StandardScaler())]),
#                                                                          ['cap-color-rate']),
#                                                                         ('cat_pipeline',
#                                                                          Pipeline(steps=[('impute',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('...
#                                                                          ['cap-shape',
#                                                                           'cap-surface',
#                                                                           'bruises',
#                                                                           'odor',
#                                                                           'stalk-shape',
#                                                                           'ring-number',
#                                                                           'ring-type',
#                                                                           'spore-print-color',
#                                                                           'population',
#                                                                           'habitat'])])),
#                                        ('model', RandomForestClassifier())]),
#              param_grid={'model__criterion': ['entropy', 'gini'],
#                          'model__max_depth': [2, 3, 6],
#                          'model__min_samples_leaf': [2, 5, 10],
#                          'model__n_estimators': [100, 200],
#                          'model__random_state': [2020]},
#              scoring='accuracy')

# %%
# Search run id
best_run_df = mlflow.search_runs(order_by=['metrics.accuracy DESC'], max_results=1)
best_run_df
# Out:
#                              run_id experiment_id    status  \
# 0  dd4ae748407443dc82e3adf84ff3cafa             1  FINISHED
#
#                                         artifact_uri  \
# 0  /Users/jackkahod/Desktop/File/3-2/Data-Sci/211...
#
#                         start_time                         end_time  \
# 0 2024-02-12 16:20:05.848000+00:00 2024-02-12 16:20:33.549000+00:00
#
#    metrics.accuracy                                  params.param_grid  \
# 0          0.996531  {'model__criterion': ['entropy', 'gini'], 'mod...
#
#   params.n_splits tags.mlflow.source.type  \
# 0               5                   LOCAL
#
#                        tags.mlflow.log-model.history tags.mlflow.user  \
# 0  [{"run_id": "dd4ae748407443dc82e3adf84ff3cafa"...        jackkahod
#
#   tags.mlflow.runName                            tags.mlflow.source.name
# 0     sassy-chimp-269  /Users/jackkahod/anaconda3/envs/datasci/lib/py...

# %%
run_id = str(best_run_df.loc[0, 'run_id'])
print('run_id: ', run_id)
model_uri = f"runs:/{run_id}/model"
print('model_uri: ', model_uri)
# Out:
# run_id:  dd4ae748407443dc82e3adf84ff3cafa
# model_uri:  runs:/dd4ae748407443dc82e3adf84ff3cafa/model

# %%
# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(model_uri=f"runs:/{run_id}/model")

# Predict on a Pandas DataFrame.
predicted = loaded_model.predict(pd.DataFrame(X_test))

print(classification_report(y_test, predicted, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            e     0.9906    1.0000    0.9953       421
#            p     1.0000    0.9945    0.9973       732
#
#     accuracy                         0.9965      1153
#    macro avg     0.9953    0.9973    0.9963      1153
# weighted avg     0.9966    0.9965    0.9965      1153

# %%
mlflow.register_model(model_uri=model_uri, name="Murshroom")

model_name = 'Murshroom'
model_version = 1

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(model_uri=f"models:/{model_name}/{model_version}")

# Predict on a Pandas DataFrame.
predicted = loaded_model.predict(pd.DataFrame(X_test))
# Out:
# Registered model 'Murshroom' already exists. Creating a new version of this model...
# Created version '2' of model 'Murshroom'.

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test, predicted, digits=4))
print(confusion_matrix(y_test,predicted))
# Out:
#               precision    recall  f1-score   support
#
#            e     0.9906    1.0000    0.9953       421
#            p     1.0000    0.9945    0.9973       732
#
#     accuracy                         0.9965      1153
#    macro avg     0.9953    0.9973    0.9963      1153
# weighted avg     0.9966    0.9965    0.9965      1153
#
# [[421   0]
#  [  4 728]]

# %% [markdown]
# ### Initialize Database

# %%
# !mlflow ui --backend-store-uri sqlite:///mlruns.db
