# %%
# !pip install kafka-python
# !pip install avro-python3
# Out:
# Requirement already satisfied: kafka-python in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (2.0.2)
# Requirement already satisfied: avro-python3 in /Users/jackkahod/anaconda3/envs/datasci/lib/python3.9/site-packages (1.10.2)

# %%
# import required libraries
from kafka import KafkaConsumer, KafkaProducer
import avro.schema
import avro.io
import io
import hashlib, json

# %%
def serialize(schema, obj):
    bytes_writer = io.BytesIO()
    encoder = avro.io.BinaryEncoder(bytes_writer)
    writer = avro.io.DatumWriter(schema)
    writer.write(obj, encoder)
    return bytes_writer.getvalue()

# %%
def deserialize(schema, raw_bytes):
    bytes_reader = io.BytesIO(raw_bytes)
    decoder = avro.io.BinaryDecoder(bytes_reader)
    reader = avro.io.DatumReader(schema)
    return reader.read(decoder)

# %%
schema_file = 'transaction.avsc'
txschema = avro.schema.parse(open(schema_file).read())
schema_file = 'submit.avsc'
submitschema = avro.schema.parse(open(schema_file).read())
schema_file = 'result.avsc'
resultschema = avro.schema.parse(open(schema_file).read())

# %%
# Connect to kafka broker running in your local host (docker). Change this to your kafka broker if needed
kafka_broker = 'lab.aimet.tech:9092'

# %%
submitproducer = KafkaProducer(bootstrap_servers=[kafka_broker])

# %%
txconsumer = KafkaConsumer(
    'transaction',
     bootstrap_servers=[kafka_broker],
     enable_auto_commit=True,
     value_deserializer=lambda x: deserialize(txschema, x))
resultconsumer = KafkaConsumer(
    'result',
     bootstrap_servers=[kafka_broker],
     enable_auto_commit=True,
     value_deserializer=lambda x: deserialize(resultschema, x))

# %%
def gen_signature(txid, payer, payee, amount, token):
    o = {'txid': txid, 'payer': payer, 'payee': payee, 'amount': amount, 'token': token}
    return hashlib.md5(json.dumps(o, sort_keys=True).encode('utf-8')).hexdigest()

# %%
# Starting transaction consumer
for msg in txconsumer:
    
    # Setting up token and verification ID
    token = 'e6463ec70f455d19607d8c75135e4b68'
    vid = 'V458404'
    
    # Extracting transaction details
    txid = (msg.value)['txid']
    payer = (msg.value)['payer']
    payee = (msg.value)['payee']
    amount = (msg.value)['amount']

    # Constructing transaction data with verification ID, transaction ID, and signature
    transaction_data = {'vid': vid, 'txid': txid,'signature': gen_signature(txid, payer, payee, amount, token)}
    
    # Serializing transaction data
    serialized_data = serialize(submitschema, transaction_data)
    
    # Sending serialized transaction data to submitproducer
    submitproducer.send('submit', serialized_data)

    # Waiting for verification result
    for res in resultconsumer:
        if res.value['vid'] == vid and res.value['txid'] == txid:
            print(res.value)
            print()
            print('timestamp: ',res.value['timestamp'])
            print('vid: ',res.value['vid'])
            print('txid: ',res.value['txid'])
            print('checksum: ',res.value['checksum'])
            print()
            print('-------------------SUCCESS------------------------',end='\n\n\n')
            break
# Out:
# {'timestamp': 1711640859, 'vid': 'V458404', 'txid': 'TX09360', 'checksum': '8c7c27dd615e2c8f0ab6eaaa06b39d87', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640859
# vid:  V458404
# txid:  TX09360
# checksum:  8c7c27dd615e2c8f0ab6eaaa06b39d87
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640865, 'vid': 'V458404', 'txid': 'TX04451', 'checksum': '41ed79d48da67e2458e64f8c691c6dac', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640865
# vid:  V458404
# txid:  TX04451
# checksum:  41ed79d48da67e2458e64f8c691c6dac
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640874, 'vid': 'V458404', 'txid': 'TX02156', 'checksum': 'cb597ba145009afbef1e299f2a086a2d', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640874
# vid:  V458404
# txid:  TX02156
# checksum:  cb597ba145009afbef1e299f2a086a2d
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640883, 'vid': 'V458404', 'txid': 'TX02699', 'checksum': 'f8c80a95bde415197a45d75806c244fe', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640883
# vid:  V458404
# txid:  TX02699
# checksum:  f8c80a95bde415197a45d75806c244fe
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640891, 'vid': 'V458404', 'txid': 'TX04267', 'checksum': '1f1484b4c08c3c375893ec744dc93ae4', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640891
# vid:  V458404
# txid:  TX04267
# checksum:  1f1484b4c08c3c375893ec744dc93ae4
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640896, 'vid': 'V458404', 'txid': 'TX03609', 'checksum': '3be2207002ee73b8bc16db34537ec8b5', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640896
# vid:  V458404
# txid:  TX03609
# checksum:  3be2207002ee73b8bc16db34537ec8b5
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640902, 'vid': 'V458404', 'txid': 'TX05808', 'checksum': '2618354cd3222197302d7831453f6073', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640902
# vid:  V458404
# txid:  TX05808
# checksum:  2618354cd3222197302d7831453f6073
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640907, 'vid': 'V458404', 'txid': 'TX00053', 'checksum': '8a3dd326aa5a533de7b30e5e8db157f7', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640907
# vid:  V458404
# txid:  TX00053
# checksum:  8a3dd326aa5a533de7b30e5e8db157f7
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640916, 'vid': 'V458404', 'txid': 'TX09892', 'checksum': '59b83d13e94f2beae8538fc84cfa62f2', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640916
# vid:  V458404
# txid:  TX09892
# checksum:  59b83d13e94f2beae8538fc84cfa62f2
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640926, 'vid': 'V458404', 'txid': 'TX00257', 'checksum': 'f9394b52628366bb1f2357e9f38a82ac', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640926
# vid:  V458404
# txid:  TX00257
# checksum:  f9394b52628366bb1f2357e9f38a82ac
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640936, 'vid': 'V458404', 'txid': 'TX05239', 'checksum': 'ff566f4f4fd6ee09c7089a63d4c74478', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640936
# vid:  V458404
# txid:  TX05239
# checksum:  ff566f4f4fd6ee09c7089a63d4c74478
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640946, 'vid': 'V458404', 'txid': 'TX06765', 'checksum': '3e7709d06a6d4c4480d6b6f2a4fc3da0', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640946
# vid:  V458404
# txid:  TX06765
# checksum:  3e7709d06a6d4c4480d6b6f2a4fc3da0
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640952, 'vid': 'V458404', 'txid': 'TX06818', 'checksum': '347f3565bdd96d47da1284629bdf35f5', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640952
# vid:  V458404
# txid:  TX06818
# checksum:  347f3565bdd96d47da1284629bdf35f5
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640962, 'vid': 'V458404', 'txid': 'TX05806', 'checksum': '40f1647cfabaf618fe40a7d125f45311', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640962
# vid:  V458404
# txid:  TX05806
# checksum:  40f1647cfabaf618fe40a7d125f45311
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640967, 'vid': 'V458404', 'txid': 'TX00111', 'checksum': 'c88ee48ded9b7236863a1d28a43dd462', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640967
# vid:  V458404
# txid:  TX00111
# checksum:  c88ee48ded9b7236863a1d28a43dd462
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640977, 'vid': 'V458404', 'txid': 'TX08523', 'checksum': '5fec612c086633775e3b556c4003a241', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640977
# vid:  V458404
# txid:  TX08523
# checksum:  5fec612c086633775e3b556c4003a241
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640983, 'vid': 'V458404', 'txid': 'TX09285', 'checksum': 'dc6ac50bfd9240f63c742e80f52f8e33', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640983
# vid:  V458404
# txid:  TX09285
# checksum:  dc6ac50bfd9240f63c742e80f52f8e33
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640989, 'vid': 'V458404', 'txid': 'TX07894', 'checksum': '370264d8d34ff75a8f4781e9a2209095', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640989
# vid:  V458404
# txid:  TX07894
# checksum:  370264d8d34ff75a8f4781e9a2209095
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711640996, 'vid': 'V458404', 'txid': 'TX02852', 'checksum': '846115ef2de1c08fb5ac4350005d0239', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711640996
# vid:  V458404
# txid:  TX02852
# checksum:  846115ef2de1c08fb5ac4350005d0239
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641004, 'vid': 'V458404', 'txid': 'TX09833', 'checksum': '7bbae0d7e483407e20ea8eb0b730b1dc', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641004
# vid:  V458404
# txid:  TX09833
# checksum:  7bbae0d7e483407e20ea8eb0b730b1dc
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641010, 'vid': 'V458404', 'txid': 'TX03163', 'checksum': '90dca97b54f2867400e743c107801498', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641010
# vid:  V458404
# txid:  TX03163
# checksum:  90dca97b54f2867400e743c107801498
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641017, 'vid': 'V458404', 'txid': 'TX05520', 'checksum': '126d6120c18dc28203f4042d87bb98f7', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641017
# vid:  V458404
# txid:  TX05520
# checksum:  126d6120c18dc28203f4042d87bb98f7
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641024, 'vid': 'V458404', 'txid': 'TX09471', 'checksum': '38b7d8a1813b49f62121b6f9ab280f58', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641024
# vid:  V458404
# txid:  TX09471
# checksum:  38b7d8a1813b49f62121b6f9ab280f58
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641033, 'vid': 'V458404', 'txid': 'TX04764', 'checksum': '938eef2d71b8f6750d90af4cbb8d8772', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641033
# vid:  V458404
# txid:  TX04764
# checksum:  938eef2d71b8f6750d90af4cbb8d8772
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641040, 'vid': 'V458404', 'txid': 'TX02099', 'checksum': '0e47b552007cf238555287b6c57cf4cc', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641040
# vid:  V458404
# txid:  TX02099
# checksum:  0e47b552007cf238555287b6c57cf4cc
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641048, 'vid': 'V458404', 'txid': 'TX06219', 'checksum': '8073026f4c7a29643c187ba8fbb684ea', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641048
# vid:  V458404
# txid:  TX06219
# checksum:  8073026f4c7a29643c187ba8fbb684ea
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641055, 'vid': 'V458404', 'txid': 'TX03325', 'checksum': 'f41e800d68a38f4e89de708ae4b8fdde', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641055
# vid:  V458404
# txid:  TX03325
# checksum:  f41e800d68a38f4e89de708ae4b8fdde
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641064, 'vid': 'V458404', 'txid': 'TX02678', 'checksum': 'aba5bbe5e445d22ab2e6c3aeb87440bc', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641064
# vid:  V458404
# txid:  TX02678
# checksum:  aba5bbe5e445d22ab2e6c3aeb87440bc
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641073, 'vid': 'V458404', 'txid': 'TX05075', 'checksum': 'a4dd9db12ba1371aed21213b2eb72dcc', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641073
# vid:  V458404
# txid:  TX05075
# checksum:  a4dd9db12ba1371aed21213b2eb72dcc
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641079, 'vid': 'V458404', 'txid': 'TX08598', 'checksum': 'bf2cfd2ec7bc54ea2fa5df04c0550656', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641079
# vid:  V458404
# txid:  TX08598
# checksum:  bf2cfd2ec7bc54ea2fa5df04c0550656
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641086, 'vid': 'V458404', 'txid': 'TX04352', 'checksum': '51666f3806c931ee14c0c2f70a338a30', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641086
# vid:  V458404
# txid:  TX04352
# checksum:  51666f3806c931ee14c0c2f70a338a30
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641095, 'vid': 'V458404', 'txid': 'TX07334', 'checksum': '42a2561040a046af64c0e289ec5bcc79', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641095
# vid:  V458404
# txid:  TX07334
# checksum:  42a2561040a046af64c0e289ec5bcc79
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641103, 'vid': 'V458404', 'txid': 'TX08546', 'checksum': '73dc32439d613de29a849035a3bf63d6', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641103
# vid:  V458404
# txid:  TX08546
# checksum:  73dc32439d613de29a849035a3bf63d6
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641110, 'vid': 'V458404', 'txid': 'TX03627', 'checksum': '657d28546f9c024cc9f68f765eb7d7f1', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641110
# vid:  V458404
# txid:  TX03627
# checksum:  657d28546f9c024cc9f68f765eb7d7f1
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641116, 'vid': 'V458404', 'txid': 'TX07206', 'checksum': '6159f48f58d4dd639a17a3b8020a7d6a', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641116
# vid:  V458404
# txid:  TX07206
# checksum:  6159f48f58d4dd639a17a3b8020a7d6a
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641124, 'vid': 'V458404', 'txid': 'TX05196', 'checksum': 'f745b1526c3bfeb185fa6c7f72f47b29', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641124
# vid:  V458404
# txid:  TX05196
# checksum:  f745b1526c3bfeb185fa6c7f72f47b29
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641133, 'vid': 'V458404', 'txid': 'TX02611', 'checksum': '667efcbdebe13bb72c2e77cb17762848', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641133
# vid:  V458404
# txid:  TX02611
# checksum:  667efcbdebe13bb72c2e77cb17762848
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641143, 'vid': 'V458404', 'txid': 'TX05775', 'checksum': '948ee0d07675a3bd67e49675a86f039d', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641143
# vid:  V458404
# txid:  TX05775
# checksum:  948ee0d07675a3bd67e49675a86f039d
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641148, 'vid': 'V458404', 'txid': 'TX01896', 'checksum': 'd945d67fb58e7037a4af01d494825b5f', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641148
# vid:  V458404
# txid:  TX01896
# checksum:  d945d67fb58e7037a4af01d494825b5f
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641155, 'vid': 'V458404', 'txid': 'TX07435', 'checksum': '18abd228c9beef2caabf432b1e7be232', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641155
# vid:  V458404
# txid:  TX07435
# checksum:  18abd228c9beef2caabf432b1e7be232
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641164, 'vid': 'V458404', 'txid': 'TX04224', 'checksum': '9e73d5787851e9d385e402bdf2643a75', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641164
# vid:  V458404
# txid:  TX04224
# checksum:  9e73d5787851e9d385e402bdf2643a75
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641169, 'vid': 'V458404', 'txid': 'TX08272', 'checksum': '3710fa8e0c584bdeb003b6d351e9294d', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641169
# vid:  V458404
# txid:  TX08272
# checksum:  3710fa8e0c584bdeb003b6d351e9294d
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641179, 'vid': 'V458404', 'txid': 'TX06080', 'checksum': '324cdef5434b646aeea0fe7cad5ba167', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641179
# vid:  V458404
# txid:  TX06080
# checksum:  324cdef5434b646aeea0fe7cad5ba167
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641189, 'vid': 'V458404', 'txid': 'TX06211', 'checksum': '877349a0d76db5070dda887aef4e5550', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641189
# vid:  V458404
# txid:  TX06211
# checksum:  877349a0d76db5070dda887aef4e5550
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641197, 'vid': 'V458404', 'txid': 'TX00703', 'checksum': 'd948a05cb0f97704eaec40ba55f194af', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641197
# vid:  V458404
# txid:  TX00703
# checksum:  d948a05cb0f97704eaec40ba55f194af
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641204, 'vid': 'V458404', 'txid': 'TX02070', 'checksum': 'ed45283baccf14d14a50faed6c5d07b7', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641204
# vid:  V458404
# txid:  TX02070
# checksum:  ed45283baccf14d14a50faed6c5d07b7
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641209, 'vid': 'V458404', 'txid': 'TX06477', 'checksum': '14d48834a8f9a41b889ee1a9ac9283f4', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641209
# vid:  V458404
# txid:  TX06477
# checksum:  14d48834a8f9a41b889ee1a9ac9283f4
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641215, 'vid': 'V458404', 'txid': 'TX07354', 'checksum': '1ea738a6254b9348c84d3dc925b75fec', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641215
# vid:  V458404
# txid:  TX07354
# checksum:  1ea738a6254b9348c84d3dc925b75fec
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641220, 'vid': 'V458404', 'txid': 'TX04789', 'checksum': 'd51f0c421d7a7f7b072fa7bed3f6c94b', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641220
# vid:  V458404
# txid:  TX04789
# checksum:  d51f0c421d7a7f7b072fa7bed3f6c94b
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641229, 'vid': 'V458404', 'txid': 'TX03901', 'checksum': '00e8bffc114b7de01f7954d1dec12cad', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641229
# vid:  V458404
# txid:  TX03901
# checksum:  00e8bffc114b7de01f7954d1dec12cad
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641235, 'vid': 'V458404', 'txid': 'TX07292', 'checksum': '6e3d2124932bb5f867ad3f4b8313f1e9', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641235
# vid:  V458404
# txid:  TX07292
# checksum:  6e3d2124932bb5f867ad3f4b8313f1e9
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641243, 'vid': 'V458404', 'txid': 'TX00924', 'checksum': 'c9a4088d563d25b9a3ec5a2657536b00', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641243
# vid:  V458404
# txid:  TX00924
# checksum:  c9a4088d563d25b9a3ec5a2657536b00
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641253, 'vid': 'V458404', 'txid': 'TX02563', 'checksum': '656b25ff85a316ac5da3fa4255dedb66', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641253
# vid:  V458404
# txid:  TX02563
# checksum:  656b25ff85a316ac5da3fa4255dedb66
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641261, 'vid': 'V458404', 'txid': 'TX01087', 'checksum': '591c81a857cf0dad50c66a6a2ec591e2', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641261
# vid:  V458404
# txid:  TX01087
# checksum:  591c81a857cf0dad50c66a6a2ec591e2
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641271, 'vid': 'V458404', 'txid': 'TX03955', 'checksum': 'b4b5e76a36ba326a51e1a68ab513cffa', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641271
# vid:  V458404
# txid:  TX03955
# checksum:  b4b5e76a36ba326a51e1a68ab513cffa
#
# -------------------SUCCESS------------------------
#
#
# {'timestamp': 1711641279, 'vid': 'V458404', 'txid': 'TX05570', 'checksum': '1017f1331b66b5042effdfb6ba373bac', 'code': 200, 'message': 'Confirm'}
#
# timestamp:  1711641279
# vid:  V458404
# txid:  TX05570
# checksum:  1017f1331b66b5042effdfb6ba373bac
#
# -------------------SUCCESS------------------------
